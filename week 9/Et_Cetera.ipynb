# %% [markdown]
# # set

# %%
studnets = [
    {"name":"Hermione","house":"Gryffindor"},
    {"name":"Ron","house":"Hufflepuff"},
    {"name":"Harry","house":"Gryffindor"},
    {"name":"Draco","house":"Slytherin"},
    {"name":"Luna","house":"Gryffindor"},
    {"name":"Cedric","house":"Ravenclaw"},
]

houses=[]

for student in studnets:
    if student["house"] not in houses:
        houses.append(student["house"])

for house in sorted(houses):
    print(house)
# Out:
# Gryffindor
# Hufflepuff
# Ravenclaw
# Slytherin

# %%
houses=set()

for student in studnets:
    houses.add(student["house"])

for house in sorted(houses):
    print(house)
# Out:
# Gryffindor
# Hufflepuff
# Ravenclaw
# Slytherin

# %% [markdown]
# # Global

# %%
balance =0

def main():
    print("Balance:",balance)
    deposit(100)
    withdraw(50)
    print("Balance:",balance)

def deposit(amount):
    balance+=amount

def withdraw(amount):
    balance-=amount
if __name__ == "__main__":
    main()
# Out:
# Balance: 0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 15
#      13     balance-=amount
#      14 if __name__ == "__main__":
# ---> 15     main()
#
# Cell In[4], line 5, in main()
#       3 def main():
#       4     print("Balance:",balance)
# ----> 5     deposit(100)
#       6     withdraw(50)
#       7     print("Balance:",balance)
#
# Cell In[4], line 10, in deposit(amount)
#       9 def deposit(amount):
# ---> 10     balance+=amount
#
# UnboundLocalError: cannot access local variable 'balance' where it is not associated with a value

# %%
def main():
    balance =0
    print("Balance:",balance)
    deposit(100)
    withdraw(50)
    print("Balance:",balance)

def deposit(amount):
    balance+=amount

def withdraw(amount):
    balance-=amount
if __name__ == "__main__":
    main()
# Out:
# Balance: 0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 14
#      12     balance-=amount
#      13 if __name__ == "__main__":
# ---> 14     main()
#
# Cell In[6], line 4, in main()
#       2 balance =0
#       3 print("Balance:",balance)
# ----> 4 deposit(100)
#       5 withdraw(50)
#       6 print("Balance:",balance)
#
# Cell In[6], line 9, in deposit(amount)
#       8 def deposit(amount):
# ----> 9     balance+=amount
#
# UnboundLocalError: cannot access local variable 'balance' where it is not associated with a value

# %%
balance =0


def main():
    print("Balance:",balance)
    deposit(100)
    withdraw(50)
    print("Balance:",balance)

def deposit(amount):
    global balance
    balance+=amount

def withdraw(amount):
    global balance
    balance-=amount
if __name__ == "__main__":
    main()
# Out:
# Balance: 0
# Balance: 50

# %%
class Account:
    def __init__(self):
        self._balance=0
    @property
    def balance(self):
        return self._balance
    
    def deposit(self,n):
        self._balance+=n

    def withdraw(self,n):
        self._balance-=n

def main():
    account =Account()
    print("Initial balance:", account.balance)
    account.deposit(100)
    account.withdraw(50)
    print("Final balance:", account.balance)

if __name__ =="__main__":
    main()
# Out:
# Initial balance: 0
# Final balance: 50

# %% [markdown]
# # Constants

# %%
MEOWS=3

for _ in range(MEOWS):
    print('meow')
# Out:
# meow
# meow
# meow

# %%
class Cat:
    MEOWS=3
    
    def meow(self):
        for _ in range(Cat.MEOWS):
            print('meow')

cat=Cat()

cat.meow()
# Out:
# meow
# meow
# meow

# %% [markdown]
# # type hints

# %%
# !pip install mypy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mypy
#   Obtaining dependency information for mypy from https://files.pythonhosted.org/packages/7a/cc/aa881ad051f99915887db0b5de8facc0e224295be22f92178c8f77fd8359/mypy-1.10.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading mypy-1.10.1-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.1.0 (from mypy)
#   Obtaining dependency information for typing-extensions>=4.1.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting mypy-extensions>=1.0.0 (from mypy)
#   Obtaining dependency information for mypy-extensions>=1.0.0 from https://files.pythonhosted.org/packages/2a/e2/5d3f6ada4297caebe1a2add3b126fe800c96f56dbe5d1988a2cbe0b267aa/mypy_extensions-1.0.0-py3-none-any.whl.metadata
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading mypy-1.10.1-cp311-cp311-win_amd64.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB 1.3 MB/s eta 0:00:08
#     --------------------------------------- 0.1/9.4 MB 1.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/9.4 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/9.4 MB 3.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.4 MB 5.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.0/9.4 MB 7.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.8/9.4 MB 7.8 MB/s eta 0:00:01
#    ------------------- -------------------- 4.5/9.4 MB 11.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.4/9.4 MB 12.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.4/9.4 MB 14.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 17.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 17.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 17.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 17.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 13.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 9.1/9.4 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 10.9 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, mypy-extensions, mypy
# Successfully installed mypy-1.10.1 mypy-extensions-1.0.0 typing-extensions-4.12.2
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\amroe\appdata\roaming\python\python311\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/e7/54/0c1c068542cee73d8863336e974fc881e608d0170f3af15d0c0f28644531/pip-24.1.2-py3-none-any.whl.metadata
#   Using cached pip-24.1.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.1.2-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Program Files\Python311\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mypy

# %%
def meow(n):
    for _ in range(n):
        print('meow')

number = input("Number: ")
meow(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3         print('meow')
#       5 number = input("Number: ")
# ----> 6 meow(number)
#
# Cell In[20], line 2, in meow(n)
#       1 def meow(n):
# ----> 2     for _ in range(n):
#       3         print('meow')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
def meow(n: int):
    for _ in range(n):
        print('meow')

number = input("Number: ")
meow(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       3         print('meow')
#       5 number = input("Number: ")
# ----> 6 meow(number)
#
# Cell In[21], line 2, in meow(n)
#       1 def meow(n: int):
# ----> 2     for _ in range(n):
#       3         print('meow')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# mypy meow.py
# ![image.png](attachment:image.png)

# %%
def meow(n: int):
    for _ in range(n):
        print('meow')

number: int = input("Number: ")
meow(number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       3         print('meow')
#       5 number: int = input("Number: ")
# ----> 6 meow(number)
#
# Cell In[22], line 2, in meow(n)
#       1 def meow(n: int):
# ----> 2     for _ in range(n):
#       3         print('meow')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# mypy meow.py
# ![image.png](attachment:image.png)

# %%
def meow(n: int):
    for _ in range(n):
        print('meow')

number: int = int(input("Number: "))
meow(number)
